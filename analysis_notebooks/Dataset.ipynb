# %% [markdown]
# <h1>Dataset obtained from scraping Twitter, Reddit, Facebook and HardwareZone</h1>

# %%
import pandas as pd
import matplotlib
import os

# %% [markdown]
# <h2>Twitter</h2>
#
# <p>Twitter is an American microblogging and social networking service on which users post and interact with messages known as "tweets".</p>

# %%
df_twitter = pd.read_csv(f'../twitter/dataset/{os.listdir("../twitter/dataset")[0]}')
df_twitter
# Out:
#      platform   about                   id  \
# 0     Twitter  adidas  1476623637511872532
# 1     Twitter  adidas  1476609937765773319
# 2     Twitter  adidas  1476439991500824579
# 3     Twitter  adidas  1476320107647451153
# 4     Twitter  adidas  1476274153749630983
# ...       ...     ...                  ...
# 7497  Twitter    nike  1385357124805480449
# 7498  Twitter    nike  1385356550823464963
# 7499  Twitter    nike  1385340936780087296
# 7500  Twitter    nike  1385340582655143942
# 7501  Twitter    nike  1385321410348847108
#
#                                                     url  \
# 0     https://twitter.com/TheSiteSupply/status/14766...
# 1     https://twitter.com/_shireenahmed_/status/1476...
# 2     https://twitter.com/MiKiLuka_/status/147643999...
# 3     https://twitter.com/nicekicks/status/147632010...
# 4     https://twitter.com/TCHlNONSO/status/147627415...
# ...                                                 ...
# ...

# %% [markdown]
# <h2>Reddit</h2>
#
# <p>Reddit is an American social news aggregation, web content rating, and discussion website.</p>

# %%
df_reddit = pd.read_csv(f'../reddit/dataset/{os.listdir("../reddit/dataset")[0]}')
df_reddit
# Out:
#               subreddit                 created       id  \
# 0          rickandmorty  30/12/2021 03:56:51 PM  hqk41dy
# 1              Sneakers  30/12/2021 03:53:26 PM  hqk3jne
# 2                 leafs  30/12/2021 03:53:11 PM  hqk3ibl
# 3             AskReddit  30/12/2021 03:47:17 PM  hqk2n2c
# 4      unpopularopinion  30/12/2021 03:44:16 PM  hqk278m
# ...                 ...                     ...      ...
# 7490    u_GOAT-official  25/12/2021 10:16:49 PM  hpyk4t9
# 7491              chile  25/12/2021 10:16:06 PM  hpyk1lp
# 7492           Patriots  25/12/2021 10:15:47 PM  hpyk09t
# 7493  explainlikeimfive  25/12/2021 10:07:33 PM  hpyiz8n
# 7494         AppleWatch  25/12/2021 10:06:48 PM  hpyiw4b
#
#                                                    body  score platform  \
# 0     What was original shoe?? Almost looks like Sta...      1   Reddit
# 1                                  Adidas pro boost low      1   Reddit
# ...

# %% [markdown]
# <h2>Facebook</h2>
#
# <p>Facebook is an American online social media and social networking service owned by Meta Platforms.</p>

# %%
df_facebook = pd.read_csv(f'../facebook/dataset/{os.listdir("../facebook/dataset")[0]}')
df_facebook
# Out:
#       platform   about            post_id  \
# 0     Facebook  adidas   5010819278940951
# 1     Facebook  adidas   5010819278940951
# 2     Facebook  adidas   5010819278940951
# 3     Facebook  adidas   4656178861071663
# 4     Facebook  adidas   4656178861071663
# ...        ...     ...                ...
# 3121  Facebook    Nike  10153279867648445
# 3122  Facebook    Nike  10153279867648445
# 3123  Facebook    Nike  10153279867648445
# 3124  Facebook    Nike  10153279867648445
# 3125  Facebook    Nike  10153279867648445
#
#                                                post_url            post_time  \
# 0     https://facebook.com/adidas/posts/501081927894...  2021-08-05 02:54:43
# 1     https://facebook.com/adidas/posts/501081927894...  2021-08-05 02:54:43
# 2     https://facebook.com/adidas/posts/501081927894...  2021-08-05 02:54:43
# 3     https://facebook.com/adidas/posts/465617886107...  2021-04-19 15:52:32
# ...

# %% [markdown]
# <h2>HardwareZone</h2>
#
# <p>HardwareZone is an IT-oriented Internet portal based in Singapore.</p>

# %%
df_hwz = pd.read_csv(f'../hwz/dataset/{os.listdir("../hwz/dataset")[0]}')
df_hwz
# Out:
#          platform                                          forum_url  \
# 0    HardwareZone  https://forums.hardwarezone.com.sg/threads/chi...
# 1    HardwareZone  https://forums.hardwarezone.com.sg/threads/chi...
# 2    HardwareZone  https://forums.hardwarezone.com.sg/threads/chi...
# 3    HardwareZone  https://forums.hardwarezone.com.sg/threads/chi...
# 4    HardwareZone  https://forums.hardwarezone.com.sg/threads/chi...
# ..            ...                                                ...
# 927  HardwareZone  https://forums.hardwarezone.com.sg/threads/fac...
# 928  HardwareZone  https://forums.hardwarezone.com.sg/threads/fac...
# 929  HardwareZone  https://forums.hardwarezone.com.sg/threads/fac...
# 930  HardwareZone  https://forums.hardwarezone.com.sg/threads/fac...
# 931  HardwareZone  https://forums.hardwarezone.com.sg/threads/fac...
#
#                                            forum_title  \
# 0    Chinese boycott against Nike and Adidas over X...
# ...

# %% [markdown]
# <h2>Combined dataset</h2>

# %%
df = pd.read_csv('../result.csv')
df
# Out:
#            platform                         about                       date  \
# 0           Twitter                        adidas  2021-12-30 18:38:04+00:00
# 1           Twitter                        adidas  2021-12-30 17:43:37+00:00
# 2           Twitter                        adidas  2021-12-30 06:28:19+00:00
# 3           Twitter                        adidas  2021-12-29 22:31:57+00:00
# 4           Twitter                        adidas  2021-12-29 19:29:20+00:00
# ...             ...                           ...                        ...
# 19050  HardwareZone  Factory Outlets in Hong Kong  2008-11-06 10:10:26+00:00
# 19051  HardwareZone  Factory Outlets in Hong Kong  2008-11-06 15:44:39+00:00
# 19052  HardwareZone  Factory Outlets in Hong Kong  2008-11-10 13:27:38+00:00
# 19053  HardwareZone  Factory Outlets in Hong Kong  2008-11-10 13:45:35+00:00
# 19054  HardwareZone  Factory Outlets in Hong Kong  2008-11-10 14:51:26+00:00
#
# ...

# %%
df.groupby('platform').size().plot(kind='pie',  autopct='%1.2f%%', title='Platforms')
# Out:
# <AxesSubplot:title={'center':'Platforms'}, ylabel='None'>
