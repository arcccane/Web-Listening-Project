# %% [markdown]
# <h1>Topic Modelling (gensim LDA)</h1>
# <p>Topic Modeling is an unsupervised learning approach to clustering documents, to discover topics based on their contents.</p>

# %%
import pandas as pd
import gensim
import gensim.corpora as corpora
import pyLDAvis
import pyLDAvis.gensim_models
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim import corpora, models

# %%
df = pd.read_csv('../result_clean.csv')
df[['platform','date','body','clean_body','label']]
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                               clean_body   label
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas
# 2      blessing follower life changing nfts hour orig...  adidas
# 3              south park  professor chaos nmd releasing  adidas
# 4             patronise sell  shoe fake walk fast notice  adidas
# ...                                                  ...     ...
# 14083                                      legit spoiler  adidas
# 14084            tuakong selling fake sour grape sarpork  adidas
# 14085                              nakedtoes dun share s  adidas
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas
#
# [14088 rows x 5 columns]

# %%
li = [str(body).split() for body in df['clean_body'].tolist()]
id2word = Dictionary(li)
id2word

# %%
corpus = [id2word.doc2bow(text) for text in li]
corpus[:1]
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1)]]

# %%
[[(id2word[i], freq) for i, freq in doc] for doc in corpus[:1]]
# Out:
# [[('blue', 1),
#   ('boost', 1),
#   ('coming', 1),
#   ('dazzling', 1),
#   ('ig', 1),
#   ('yankeekicks', 1),
#   ('yeezy', 1)]]

# %%
lda_model = LdaModel(corpus=corpus,
                   id2word=id2word,
                   num_topics=10, 
                   random_state=0,
                   chunksize=100,
                   alpha='auto',
                   per_word_topics=True)

doc_lda = lda_model[corpus]
for i in lda_model.print_topics():
    print(f"{i[0]}\n{i[1].replace(' ','')}")
# Out:
# 0
# 0.080*"brand"+0.077*"product"+0.036*"support"+0.034*"year"+0.020*"xinjiang"+0.016*"guy"+0.015*"share"+0.014*"god"+0.013*"click"+0.012*"social"
# 1
# 0.063*"balance"+0.037*"website"+0.026*"color"+0.024*"play"+0.023*"wait"+0.022*"matter"+0.021*"respect"+0.021*"hey"+0.020*"basketball"+0.016*"cut"
# 2
# 0.091*"buy"+0.050*"time"+0.027*"price"+0.024*"lol"+0.024*"love"+0.019*"market"+0.019*"shop"+0.015*"walking"+0.014*"lose"+0.012*"place"
# 3
# 0.060*"china"+0.050*"pair"+0.032*"boycott"+0.031*"sport"+0.026*"cheap"+0.019*"puma"+0.018*"lot"+0.017*"country"+0.017*"pay"+0.017*"told"
# 4
# 0.027*"good"+0.024*"people"+0.024*"la"+0.019*"store"+0.016*"order"+0.012*"size"+0.011*"para"+0.011*"buying"+0.009*"el"+0.009*"cotton"
# 5
# 0.039*"running"+0.034*"customer"+0.031*"fake"+0.019*"sell"+0.016*"hope"+0.014*"american"+0.013*"stand"+0.013*"family"+0.013*"gift"+0.012*"feel"
# 6
# 0.058*"bought"+0.038*"online"+0.027*"issue"+0.023*"nice"+0.023*"era"+0.021*"woman"+0.019*"shirt"+0.018*"check"+0.017*"una"+0.016*"long"
# 7
# 0.025*"boost"+0.024*"air"+0.024*"sneaker"+0.020*"react"+0.019*"work"+0.016*"quality"+0.016*"team"+0.015*"man"+0.015*"contract"+0.014*"purchase"
# 8
# 0.075*"shoe"+0.026*"wear"+0.025*"company"+0.018*"money"+0.014*"month"+0.010*"gagt"+0.010*"chinese"+0.009*"da"+0.009*"service"+0.009*"outlet"
# 9
# 0.056*"day"+0.044*"sale"+0.023*"care"+0.017*"thought"+0.017*"deal"+0.016*"business"+0.015*"wearing"+0.015*"lost"+0.014*"wow"+0.013*"est"

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 8     -0.262174 -0.302125       1        1  23.227167
# 4     -0.291664  0.290323       2        1  16.331667
# 7      0.028752 -0.070091       3        1  11.513538
# 3      0.055553  0.043567       4        1   9.961695
# 5      0.046662 -0.053826       5        1   8.354043
# 0      0.096994 -0.006322       6        1   8.076326
# 2      0.066457  0.022979       7        1   7.621334
# 9      0.095207  0.021847       8        1   6.547768
# 6      0.076210  0.011958       9        1   6.327044
# 1      0.088002  0.041690      10        1   2.039419, topic_info=          Term         Freq        Total Category  logprob  loglift
# 41        shoe  3624.000000  3624.000000  Default  30.0000  30.0000
# 9          buy  1432.000000  1432.000000  Default  29.0000  29.0000
# 223      brand  1338.000000  1338.000000  Default  28.0000  28.0000
# 649    product  1281.000000  1281.000000  Default  27.0000  27.0000
# 1189     china  1232.000000  1232.000000  Default  26.0000  26.0000
# ...        ...          ...          ...      ...      ...      ...
# 7220     bible    23.948544    25.130906  Topic10  -5.1725   3.8443
# 800    include    16.963820    17.851836  Topic10  -5.5174   3.8415
# 20529   wasted    19.169297    20.243143  Topic10  -5.3951   3.8380
# 7102     study    20.414187    21.723961  Topic10  -5.3322   3.8303
# 15169    loser    28.801744    39.132595  Topic10  -4.9880   3.5860
#
# [373 rows x 6 columns], token_table=       Topic      Freq      Term
# term
# 1255       2  0.991545   account
# 468        1  0.044251   address
# 468        9  0.954552   address
# 2572       3  0.998386       air
# 22068      7  0.983005      aldm
# ...      ...       ...       ...
# 3595       6  0.997795  xinjiang
# 129        3  0.271004      year
# 129        6  0.727431      year
# 6          4  0.992253     yeezy
# 3736       8  0.985747      zoom
#
# [428 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[9, 5, 8, 4, 6, 1, 3, 10, 7, 2])
