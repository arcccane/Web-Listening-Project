# %% [markdown]
# <h1>Topic Modelling with KMeans text clustering</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../result_clean.csv')
df
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                              token_words  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoes', 'fake...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fakes', 'sour', 'grape...
# 14085                ['nakedtoes', 'dun', 'share', 'ss']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               lemmatized  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoe', 'fake'...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fake', 'sour', 'grape'...
# 14085                 ['nakedtoes', 'dun', 'share', 's']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               clean_body   label
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas
# 2      blessing follower life changing nfts hour orig...  adidas
# 3              south park  professor chaos nmd releasing  adidas
# 4             patronise sell  shoe fake walk fast notice  adidas
# ...                                                  ...     ...
# 14083                                      legit spoiler  adidas
# 14084            tuakong selling fake sour grape sarpork  adidas
# 14085                              nakedtoes dun share s  adidas
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas
#
# [14088 rows x 7 columns]

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5, max_df=0.95)
tf = vectorizer.fit_transform(df['clean_body'].astype('U')).toarray()
tf_feature_names = vectorizer.get_feature_names_out()
tf_feature_names
# Out:
# array(['abc', 'aber', 'abercrombie', ..., 'zwrotu', 'zx', 'zyon'],
#       dtype=object)

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(tf)
clusters = kmeans.labels_
clusters
# Out:
# array([4, 0, 0, ..., 0, 0, 0])

# %%
pca = PCA(n_components=2, random_state=42)
pca_vecs = pca.fit_transform(tf)
x0 = pca_vecs[:, 0]
x1 = pca_vecs[:, 1]

# %%
df['cluster'] = clusters
df['x0'] = x0
df['x1'] = x1
df
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                              token_words  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoes', 'fake...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fakes', 'sour', 'grape...
# 14085                ['nakedtoes', 'dun', 'share', 'ss']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               lemmatized  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoe', 'fake'...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fake', 'sour', 'grape'...
# 14085                 ['nakedtoes', 'dun', 'share', 's']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               clean_body   label  cluster  \
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas        4
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas        0
# 2      blessing follower life changing nfts hour orig...  adidas        0
# 3              south park  professor chaos nmd releasing  adidas        0
# 4             patronise sell  shoe fake walk fast notice  adidas        2
# ...                                                  ...     ...      ...
# 14083                                      legit spoiler  adidas        0
# 14084            tuakong selling fake sour grape sarpork  adidas        0
# 14085                              nakedtoes dun share s  adidas        0
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas        0
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas        0
#
#              x0        x1
# 0     -0.012893  0.074832
# 1     -0.024011 -0.038751
# 2     -0.017930 -0.017075
# 3     -0.013635  0.002007
# 4     -0.027517 -0.067544
# ...         ...       ...
# 14083 -0.012322 -0.009990
# 14084 -0.020748 -0.026498
# 14085 -0.013455 -0.012791
# 14086 -0.014623 -0.015006
# 14087 -0.015092 -0.019978
#
# [14088 rows x 10 columns]

# %%
def get_top_keywords(n_terms):
    """This function returns the keywords for each centroid of the KMeans"""
    df = pd.DataFrame(tf).groupby(clusters).mean() # groups the TF-IDF vector by cluster
    for i, r in df.iterrows():
        print('\nCluster {}'.format(i))
        # for each row of the dataframe, find the n terms that have the highest tf idf score
        print(', '.join([tf_feature_names[t] for t in np.argsort(r)[-n_terms:]]))
        
get_top_keywords(10)
# Out:
# Cluster 0
# buy, kit, people, good, jersey, wearing, wear, year, time, brand
#
# Cluster 1
# aqua, wave, monarch, force, react, scott, travis, patta, max, air
#
# Cluster 2
# company, size, bought, wear, running, product, buy, good, pair, shoe
#
# Cluster 3
# union, pink, offwhite, upcoming, high, low, image, sb, official, dunk
#
# Cluster 4
# ash, runner, december, blue, mx, slide, official, image, boost, yeezy

# %%
plt.figure(figsize=(12, 7))
plt.title("TF-IDF + KMeans clustering", fontdict={"fontsize": 18})
plt.xlabel("X0", fontdict={"fontsize": 16})
plt.ylabel("X1", fontdict={"fontsize": 16})
sns.scatterplot(data=df, x='x0', y='x1', hue='cluster', palette="viridis")
plt.show()
