# %% [markdown]
# <h1>Topic Modelling (sklearn NMF)</h1>
# <p>Topic Modeling is an unsupervised learning approach to clustering documents, to discover topics based on their contents.</p>

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF

# %%
df = pd.read_csv('../result_sentiment.csv')
df
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                              token_words  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoes', 'fake...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fakes', 'sour', 'grape...
# 14085                ['nakedtoes', 'dun', 'share', 'ss']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               lemmatized  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoe', 'fake'...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fake', 'sour', 'grape'...
# 14085                 ['nakedtoes', 'dun', 'share', 's']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               clean_body   label  \
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas
# 2      blessing follower life changing nfts hour orig...  adidas
# 3              south park  professor chaos nmd releasing  adidas
# 4             patronise sell  shoe fake walk fast notice  adidas
# ...                                                  ...     ...
# 14083                                      legit spoiler  adidas
# 14084            tuakong selling fake sour grape sarpork  adidas
# 14085                              nakedtoes dun share s  adidas
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas
#
#                                                   scores  compound  \
# 0      {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compou...    0.4019
# 1      {'neg': 0.232, 'neu': 0.452, 'pos': 0.316, 'co...    0.1280
# 2      {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4939
# 3      {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'comp...   -0.5719
# 4      {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'comp...   -0.4767
# ...                                                  ...       ...
# 14083  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14084  {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'comp...   -0.4767
# 14085  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...    0.2960
# 14086  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14087  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...    0.3400
#
#       sentiment_type
# 0           POSITIVE
# 1           POSITIVE
# 2           POSITIVE
# 3           NEGATIVE
# 4           NEGATIVE
# ...              ...
# 14083        NEUTRAL
# 14084       NEGATIVE
# 14085       POSITIVE
# 14086        NEUTRAL
# 14087       POSITIVE
#
# [14088 rows x 10 columns]

# %%
no_of_words = df['clean_body'].apply(lambda x: len(str(x).split(' ')))
avg = round(no_of_words.sum()/len(no_of_words), 2)
print("Average no of words for each row: ", avg)
# Out:
# Average no of words for each row:  15.45

# %% [markdown]
# <h2>CountVectorizer</h2>

# %%
# tfidf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=25)
# tfidf = tfidf_vectorizer.fit_transform(df['clean_body'].astype('U'))
# tfidf_feature_names = tfidf_vectorizer.get_feature_names()
# tfidf_feature_names

vectorizer = CountVectorizer(max_df=0.9, min_df=25, analyzer='word')
tf = vectorizer.fit_transform(df['clean_body'].astype('U')).toarray()
tf_feature_names = vectorizer.get_feature_names_out()
tf_feature_names
# Out:
# array(['absolutely', 'abuse', 'access', ..., 'za', 'zapatillas', 'zoom'],
#       dtype=object)

# %%
len(tf_feature_names)
# Out:
# 1299

# %% [markdown]
# <h2>NMF</h2>

# %%
nmf_model = NMF(n_components=10, random_state=0, alpha=.1, l1_ratio=.5, max_iter=10000)
nmf_model.fit(tf)
# Out:
# NMF(alpha=0.1, l1_ratio=0.5, max_iter=10000, n_components=10, random_state=0)

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic words %d" % (topic_idx)] = ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic weights %d" % (topic_idx)] = ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

no_top_words = 10
df_nmf_topics = display_topics(nmf_model, tf_feature_names, no_top_words)
df_nmf_topics
# Out:
#   Topic words 0 Topic weights 0 Topic words 1 Topic weights 1 Topic words 2  \
# 0          post             7.4          shoe            12.6        jersey
# 1      facebook             6.4          pair             2.7        reebok
# 2     september             4.3       running             1.0         large
# 3           tax             1.0          wear             1.0            xl
# 4     instagram             0.6          foot             0.8        medium
# 5     president             0.6        amazon             0.8         small
# 6      official             0.5        bought             0.7           red
# 7      american             0.5         store             0.7          star
# 8          plan             0.5         month             0.7          york
# 9          rate             0.5      customer             0.6       chicago
#
#   Topic weights 2 Topic words 3 Topic weights 3 Topic words 4 Topic weights 4  \
# 0             8.4            da             4.0       company             4.7
# 1             4.0            um             3.3       product             4.3
# 2             2.4           por             2.7           buy             2.6
# 3             1.7          para             2.6         brand             2.5
# 4             1.7            em             2.6         money             2.5
# 5             1.3            se             2.3      consumer             2.0
# 6             0.8          como             2.3      customer             2.0
# 7             0.7            ma             2.1        market             1.8
# 8             0.5          mais             2.0          sell             1.5
# 9             0.5            ao             1.7         store             1.3
#
#   Topic words 5 Topic weights 5 Topic words 6 Topic weights 6 Topic words 7  \
# 0            le             5.3         ampxb             7.9           air
# 1            la             5.2            xl             0.9          size
# 2            il             2.5            za             0.9        jordan
# 3            de             2.0       supreme             0.5          dunk
# 4           par             1.9           air             0.4         retro
# 5           est             1.8        travis             0.4         yeezy
# 6            pa             1.6           max             0.3      offwhite
# 7           une             1.2        jacket             0.3         boost
# 8            se             1.0        retail             0.3         force
# 9            du             0.8         batch             0.3           max
#
#   Topic weights 7 Topic words 8 Topic weights 8 Topic words 9 Topic weights 9
# 0             5.7          time             4.4        people             7.2
# 1             5.3         video             2.1         china             3.1
# 2             4.3          year             2.1       youtube             2.3
# 3             3.0          good             2.0       country             1.1
# 4             2.7          west             1.9          year             1.1
# 5             1.7         album             1.5         child             0.9
# 6             1.4           day             1.5    government             0.8
# 7             1.3          pair             1.4         money             0.7
# 8             0.9          face             1.3      american             0.7
# 9             0.9          work             1.3          note             0.7

# %%
topic_results = nmf_model.transform(tf)
df['topic_no'] = topic_results.argmax(axis=1)
df
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                              token_words  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoes', 'fake...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fakes', 'sour', 'grape...
# 14085                ['nakedtoes', 'dun', 'share', 'ss']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               lemmatized  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoe', 'fake'...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fake', 'sour', 'grape'...
# 14085                 ['nakedtoes', 'dun', 'share', 's']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               clean_body   label  \
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas
# 2      blessing follower life changing nfts hour orig...  adidas
# 3              south park  professor chaos nmd releasing  adidas
# 4             patronise sell  shoe fake walk fast notice  adidas
# ...                                                  ...     ...
# 14083                                      legit spoiler  adidas
# 14084            tuakong selling fake sour grape sarpork  adidas
# 14085                              nakedtoes dun share s  adidas
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas
#
#                                                   scores  compound  \
# 0      {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compou...    0.4019
# 1      {'neg': 0.232, 'neu': 0.452, 'pos': 0.316, 'co...    0.1280
# 2      {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4939
# 3      {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'comp...   -0.5719
# 4      {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'comp...   -0.4767
# ...                                                  ...       ...
# 14083  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14084  {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'comp...   -0.4767
# 14085  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...    0.2960
# 14086  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14087  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...    0.3400
#
#       sentiment_type  topic_no
# 0           POSITIVE         7
# 1           POSITIVE         4
# 2           POSITIVE         8
# 3           NEGATIVE         8
# 4           NEGATIVE         1
# ...              ...       ...
# 14083        NEUTRAL         0
# 14084       NEGATIVE         4
# 14085       POSITIVE         4
# 14086        NEUTRAL         4
# 14087       POSITIVE         8
#
# [14088 rows x 11 columns]

# %%
def map_topics(model, feature_names):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict[topic_idx] = ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topic_dict

topics_map = map_topics(nmf_model, tf_feature_names)
df['topic_words'] = df['topic_no'].map(topics_map)
df
# Out:
#            platform                 date  \
# 0           Twitter  30-12-2021 18:38:04
# 1           Twitter  30-12-2021 17:43:37
# 2           Twitter  30-12-2021 06:28:19
# 3           Twitter  29-12-2021 22:31:57
# 4           Twitter  29-12-2021 19:29:20
# ...             ...                  ...
# 14083  HardwareZone  23-08-2018 13:56:42
# 14084  HardwareZone  23-08-2018 14:02:18
# 14085  HardwareZone  23-08-2018 14:03:42
# 14086  HardwareZone  23-08-2018 14:34:13
# 14087  HardwareZone  23-08-2018 14:36:16
#
#                                                     body  \
# 0      adidas Yeezy Boost 350 V2 “Dazzling Blue” 👟\n\...
# 1      Am over the worst of Omicron. Alhumdullilah. I...
# 2      🎁 I'm blessing 1 follower with life changing N...
# 3      South Park and adidas have a new “Professor Ch...
# 4      Please patronise me, I sell Adidas shoes for 1...
# ...                                                  ...
# 14083                            All are legit.\nSpoiler
# 14084  Tuakong said:\nThose who say END selling fakes...
# 14085  Nakedtoes said:\nMight as well dun said..\n\ny...
# 14086  Prinsloo said:\nAll are legit.\nSpoiler\n\n\n\...
# 14087  Outramkia said:\nWah seh powerlah prinsloo. Al...
#
#                                              token_words  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoes', 'fake...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fakes', 'sour', 'grape...
# 14085                ['nakedtoes', 'dun', 'share', 'ss']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               lemmatized  \
# 0      ['adidas', 'yeezy', 'boost', 'dazzling', 'blue...
# 1      ['worst', 'omicron', 'alhumdullilah', 'cupcake...
# 2      ['blessing', 'follower', 'life', 'changing', '...
# 3      ['south', 'park', 'adidas', 'professor', 'chao...
# 4      ['patronise', 'sell', 'adidas', 'shoe', 'fake'...
# ...                                                  ...
# 14083                               ['legit', 'spoiler']
# 14084  ['tuakong', 'selling', 'fake', 'sour', 'grape'...
# 14085                 ['nakedtoes', 'dun', 'share', 's']
# 14086  ['prinsloo', 'legit', 'spoiler', 'wah', 'seh',...
# 14087  ['outramkia', 'wah', 'seh', 'powerlah', 'prins...
#
#                                               clean_body   label  \
# 0        yeezy boost dazzling blue coming yankeekicks ig  adidas
# 1      worst omicron alhumdullilah cupcake breakfast ...  adidas
# 2      blessing follower life changing nfts hour orig...  adidas
# 3              south park  professor chaos nmd releasing  adidas
# 4             patronise sell  shoe fake walk fast notice  adidas
# ...                                                  ...     ...
# 14083                                      legit spoiler  adidas
# 14084            tuakong selling fake sour grape sarpork  adidas
# 14085                              nakedtoes dun share s  adidas
# 14086  prinsloo legit spoiler wah seh powerlah prinsl...  adidas
# 14087  outramkia wah seh powerlah prinsloo allike shi...  adidas
#
#                                                   scores  compound  \
# 0      {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compou...    0.4019
# 1      {'neg': 0.232, 'neu': 0.452, 'pos': 0.316, 'co...    0.1280
# 2      {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4939
# 3      {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'comp...   -0.5719
# 4      {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'comp...   -0.4767
# ...                                                  ...       ...
# 14083  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14084  {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'comp...   -0.4767
# 14085  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...    0.2960
# 14086  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14087  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...    0.3400
#
#       sentiment_type  topic_no  \
# 0           POSITIVE         7
# 1           POSITIVE         4
# 2           POSITIVE         8
# 3           NEGATIVE         8
# 4           NEGATIVE         1
# ...              ...       ...
# 14083        NEUTRAL         0
# 14084       NEGATIVE         4
# 14085       POSITIVE         4
# 14086        NEUTRAL         4
# 14087       POSITIVE         8
#
#                                              topic_words
# 0      [air, size, jordan, dunk, retro, yeezy, offwhi...
# 1      [company, product, buy, brand, money, consumer...
# 2      [time, video, year, good, west, album, day, pa...
# 3      [time, video, year, good, west, album, day, pa...
# 4      [shoe, pair, running, wear, foot, amazon, boug...
# ...                                                  ...
# 14083  [post, facebook, september, tax, instagram, pr...
# 14084  [company, product, buy, brand, money, consumer...
# 14085  [company, product, buy, brand, money, consumer...
# 14086  [company, product, buy, brand, money, consumer...
# 14087  [time, video, year, good, west, album, day, pa...
#
# [14088 rows x 12 columns]

# %%
df.groupby('topic_no').size().plot(kind='bar', title='Topics distribution')
# Out:
# <AxesSubplot:title={'center':'Topics distribution'}, xlabel='topic_no'>
